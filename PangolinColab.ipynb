# %% [markdown]
# <a href="https://colab.research.google.com/github/Good-lei/Pangolin-Colab/blob/main/PangolinColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Running Pangolin on Colab

# %% [markdown]
# 0. By default, Colab will not use a GPU. To use a GPU, choose: Runtime -> Change runtime type -> GPU.

# %% [markdown]
# 1. Install Pangolin and dependencies

# %%
# !pip install PyVCF3 gffutils biopython pandas pyfastx
# !git clone https://github.com/Good-lei/Pangolin-Colab.git
# %cd Pangolin-Colab
# !pip install .
# %cd /content
# Out:
# Requirement already satisfied: PyVCF3 in /usr/local/lib/python3.12/dist-packages (1.0.4)
# Requirement already satisfied: gffutils in /usr/local/lib/python3.12/dist-packages (0.13)
# Requirement already satisfied: biopython in /usr/local/lib/python3.12/dist-packages (1.86)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: pyfastx in /usr/local/lib/python3.12/dist-packages (2.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from PyVCF3) (75.2.0)
# Requirement already satisfied: pyfaidx>=0.5.5.2 in /usr/local/lib/python3.12/dist-packages (from gffutils) (0.9.0.3)
# Requirement already satisfied: argh>=0.26.2 in /usr/local/lib/python3.12/dist-packages (from gffutils) (0.31.3)
# Requirement already satisfied: argcomplete>=1.9.4 in /usr/local/lib/python3.12/dist-packages (from gffutils) (3.6.3)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from gffutils) (3.20.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from biopython) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pyfaidx>=0.5.5.2->gffutils) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Cloning into 'Pangolin-Colab'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 112 (delta 6), reused 0 (delta 0), pack-reused 100 (from 1)
# Receiving objects: 100% (112/112), 160.06 MiB | 26.71 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Updating files: 100% (155/155), done.
# /content/Pangolin-Colab
# Processing /content/Pangolin-Colab
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pangolin
#   Building wheel for pangolin (setup.py) ... done
#   Created wheel for pangolin: filename=pangolin-1.0.2-py3-none-any.whl size=167816602 sha256=8a902be47752c65fcfb169b0889db410400a21c81766f08001a1bb04c91d7b83
#   Stored in directory: /root/.cache/pip/wheels/b0/cb/70/33c4da721755bfdc948cfd4b63fb27c2aa7a4fc658f6f4dec0
# Successfully built pangolin
# Installing collected packages: pangolin
#   Attempting uninstall: pangolin
#     Found existing installation: pangolin 1.0.2
#     Uninstalling pangolin-1.0.2:
#       Successfully uninstalled pangolin-1.0.2
# Successfully installed pangolin-1.0.2
# /content

# %%
# GRCh37 files
##!wget ftp://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_30/GRCh37_mapping/GRCh37.primary_assembly.genome.fa.gz
#!wget https://www.dropbox.com/sh/6zo0aegoalvgd9f/AAA9Q90Pi1UqSzX99R_NM803a/gencode.v38lift37.annotation.db

# GRCh38 files
# !wget https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_38/GRCh38.primary_assembly.genome.fa.gz
# !wget https://www.dropbox.com/sh/6zo0aegoalvgd9f/AADOhGYJo8tbUhpscp3wSFj6a/gencode.v38.annotation.db
# Out:
# --2025-11-09 08:40:27--  https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_38/GRCh38.primary_assembly.genome.fa.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length:
dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 380366848 (363M) [application/octet-stream]
# Saving to: ‘gencode.v38.annotation.db’
#
# gencode.v38.annotat 100%[===================>] 362.75M  84.7MB/s    in 4.3s
#
# 2025-11-09 08:41:02 (84.8 MB/s) - ‘gencode.v38.annotation.db’ saved [380366848/380366848]

# %%
ls
# Out:
# gencode.v38.annotation.db             Pangolin-Colab/
# GRCh38.primary_assembly.genome.fa.gz

# %%
cat Pangolin-Colab/examples/UNC13A.test.vcf
# Out:
# ##fileformat=VCFv4.2
# ##reference=GRCh38
# ##contig=<ID=chr1,length=248956422,assembly=GRCh38>
# ##contig=<ID=chr2,length=242193529,assembly=GRCh38>
# ##contig=<ID=chr3,length=198295559,assembly=GRCh38>
# ##contig=<ID=chr4,length=190214555,assembly=GRCh38>
# ##contig=<ID=chr5,length=181538259,assembly=GRCh38>
# ##contig=<ID=chr6,length=170805979,assembly=GRCh38>
# ##contig=<ID=chr7,length=159345973,assembly=GRCh38>
# ##contig=<ID=chr8,length=145138636,assembly=GRCh38>
# ##contig=<ID=chr9,length=138394717,assembly=GRCh38>
# ##contig=<ID=chr10,length=133797422,assembly=GRCh38>
# ##contig=<ID=chr11,length=135086622,assembly=GRCh38>
# ##contig=<ID=chr12,length=133275309,assembly=GRCh38>
# ##contig=<ID=chr13,length=114364328,assembly=GRCh38>
# ##contig=<ID=chr14,length=107043718,assembly=GRCh38>
# ##contig=<ID=chr15,length=101991189,assembly=GRCh38>
# ##contig=<ID=chr16,length=90338345,assembly=GRCh38>
# ##contig=<ID=chr17,length=83257441,assembly=GRCh38>
# ##contig=<ID=chr18,length=80373285,assembly=GRCh38>
# ##contig=<ID=chr19,length=58617616,assembly=GRCh38>
# ##contig=<ID=chr20,length=64444167,assembly=GRCh38>
# ##contig=<ID=chr21,length=46709983,assembly=GRCh38>
# ##contig=<ID=chr22,length=50818468,assembly=GRCh38>
# ##contig=<ID=chrX,length=156040895,assembly=GRCh38>
# ##contig=<ID=chrY,length=57227415,assembly=GRCh38>
# #CHROM  POS  ID  REF  ALT  QUAL  FILTER  INFO
# chr19	17642430	.	C	G	.	.	.

# %% [markdown]
# 3. Run Pangolin

# %%
# !python Pangolin-Colab/pangolin/pangolin.py Pangolin-Colab/examples/UNC13A.test.vcf GRCh38.primary_assembly.genome.fa.gz gencode.v38.annotation.db unc13a.pangolin
# Out:
# /content/Pangolin-Colab/pangolin/pangolin.py:2: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_filename
# Using GPU
